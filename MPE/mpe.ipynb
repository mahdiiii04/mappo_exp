# %%
from torchrl.envs.libs.pettingzoo import PettingZooEnv

# %%
env = PettingZooEnv(
    task="simple_spread_v3",
    parallel=True,          
    seed=0,
    continuous_actions=False
)

# %%
env.observation_spec
# Out:
# Composite(
#     agent: Composite(
#         observation: UnboundedContinuous(
#             shape=torch.Size([3, 18]),
#             space=ContinuousBox(
#                 low=Tensor(shape=torch.Size([3, 18]), device=cpu, dtype=torch.float32, contiguous=True),
#                 high=Tensor(shape=torch.Size([3, 18]), device=cpu, dtype=torch.float32, contiguous=True)),
#             device=cpu,
#             dtype=torch.float32,
#             domain=continuous),
#         device=None,
#         shape=torch.Size([3]),
#         data_cls=None),
#     device=None,
#     shape=torch.Size([]),
#     data_cls=None)

# %%
env.action_spec
# Out:
# Composite(
#     agent: Composite(
#         action: Categorical(
#             shape=torch.Size([3]),
#             space=CategoricalBox(n=5),
#             device=cpu,
#             dtype=torch.int64,
#             domain=discrete),
#         device=None,
#         shape=torch.Size([3]),
#         data_cls=None),
#     device=None,
#     shape=torch.Size([]),
#     data_cls=None)

# %%
from torchrl.envs.libs.vmas import VmasEnv

env = VmasEnv(
        scenario="balance",
        num_envs=1,
        continuous_actions=False,
        max_steps=100,
        device="cpu",
        seed=0,
    )

# %%
env.observation_spec
# Out:
# Composite(
#     agents: Composite(
#         observation: UnboundedContinuous(
#             shape=torch.Size([1, 3, 16]),
#             space=ContinuousBox(
#                 low=Tensor(shape=torch.Size([1, 3, 16]), device=cpu, dtype=torch.float32, contiguous=True),
#                 high=Tensor(shape=torch.Size([1, 3, 16]), device=cpu, dtype=torch.float32, contiguous=True)),
#             device=cpu,
#             dtype=torch.float32,
#             domain=continuous),
#         info: Composite(
#             pos_rew: UnboundedContinuous(
#                 shape=torch.Size([1, 3, 1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1, 3, 1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1, 3, 1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             ground_rew: UnboundedContinuous(
#                 shape=torch.Size([1, 3, 1]),
#                 space=ContinuousBox(
#                     low=Tensor(shape=torch.Size([1, 3, 1]), device=cpu, dtype=torch.float32, contiguous=True),
#                     high=Tensor(shape=torch.Size([1, 3, 1]), device=cpu, dtype=torch.float32, contiguous=True)),
#                 device=cpu,
#                 dtype=torch.float32,
#                 domain=continuous),
#             device=cpu,
#             shape=torch.Size([1, 3]),
#             data_cls=None),
#         device=cpu,
#         shape=torch.Size([1, 3]),
#         data_cls=None),
#     device=cpu,
#     shape=torch.Size([1]),
#     data_cls=None)

# %%
env.action_spec
# Out:
# Composite(
#     agents: Composite(
#         action: Categorical(
#             shape=torch.Size([1, 3]),
#             space=CategoricalBox(n=9),
#             device=cpu,
#             dtype=torch.int64,
#             domain=discrete),
#         device=cpu,
#         shape=torch.Size([1, 3]),
#         data_cls=None),
#     device=cpu,
#     shape=torch.Size([1]),
#     data_cls=None)
