# %%
print("hello")

# %%
# !git clone https://github.com/mahdiiii04/mappo_exp

# %%
# %cd mappo_exp/DynamicVMAS

# %%
# !pip install torchrl
# !pip install vmas
# !pip install "moviepy<2.0.0"
# !pip install hydra-core
