# %%
from torchrl.envs.libs.vmas import VmasEnv

# %%
env = VmasEnv(
    scenario="simple_adversary",
    continuous_actions=False,
    num_envs=1,
    max_steps=100,
)

# %%
env.action_spec
# Out:
# Composite(
#     adversary: Composite(
#         action: Categorical(
#             shape=torch.Size([1, 1]),
#             space=CategoricalBox(n=9),
#             device=cpu,
#             dtype=torch.int64,
#             domain=discrete),
#         device=None,
#         shape=torch.Size([1, 1]),
#         data_cls=None),
#     agent: Composite(
#         action: Categorical(
#             shape=torch.Size([1, 2]),
#             space=CategoricalBox(n=9),
#             device=cpu,
#             dtype=torch.int64,
#             domain=discrete),
#         device=None,
#         shape=torch.Size([1, 2]),
#         data_cls=None),
#     device=None,
#     shape=torch.Size([1]),
#     data_cls=None)
